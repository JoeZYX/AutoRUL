# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import time
from utilities import *
from sklearn.metrics import mean_squared_error
import os
from datetime import datetime

# %%
# get current directory
path = os.getcwd()
parent_dir = os.path.abspath(os.path.join(path, os.pardir))

# %%
waterpump_data = pd.read_csv(f"{parent_dir}\\FeedbackBoost\\Data\\waterpump_raw\\waterpump.csv")

# %%
waterpump_data
# Out:
#         Unnamed: 0            timestamp  sensor_00  sensor_01  sensor_02  \
# 0                0  2018-04-01 00:00:00   2.465394   47.09201  53.211800
# 1                1  2018-04-01 00:01:00   2.465394   47.09201  53.211800
# 2                2  2018-04-01 00:02:00   2.444734   47.35243  53.211800
# 3                3  2018-04-01 00:03:00   2.460474   47.09201  53.168400
# 4                4  2018-04-01 00:04:00   2.445718   47.13541  53.211800
# ...            ...                  ...        ...        ...        ...
# 220315      220315  2018-08-31 23:55:00   2.407350   47.69965  50.520830
# 220316      220316  2018-08-31 23:56:00   2.400463   47.69965  50.564240
# 220317      220317  2018-08-31 23:57:00   2.396528   47.69965  50.520830
# 220318      220318  2018-08-31 23:58:00   2.406366   47.69965  50.520832
# 220319      220319  2018-08-31 23:59:00   2.396528   47.69965  50.520832
#
#         sensor_03   sensor_04  sensor_05  sensor_06  sensor_07  ...  \
# ...

# %%
df = waterpump_data.copy()

# %%
col_to_drop = ["Unnamed: 0"]
df = df.drop(columns= col_to_drop)
# timestamp in minutes tact
df.head()
# Out:
#              timestamp  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_43  sensor_44  \
# 0   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 1   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 2   73.54598   13.32465   16.03733   15.61777  ...   41.66666  39.351852
# 3   76.98898   13.31742   16.24711   15.69734  ...   40.88541  39.062500
# 4   76.58897   13.35359   16.21094   15.69734  ...   41.40625  38.773150
#
# ...

# %%
df.rename(columns={'timestamp': 'cycle'}, inplace = True)

# %%
df.head()
# Out:
#                  cycle  sensor_00  sensor_01  sensor_02  sensor_03  sensor_04  \
# 0  2018-04-01 00:00:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 1  2018-04-01 00:01:00   2.465394   47.09201    53.2118  46.310760   634.3750
# 2  2018-04-01 00:02:00   2.444734   47.35243    53.2118  46.397570   638.8889
# 3  2018-04-01 00:03:00   2.460474   47.09201    53.1684  46.397568   628.1250
# 4  2018-04-01 00:04:00   2.445718   47.13541    53.2118  46.397568   636.4583
#
#    sensor_05  sensor_06  sensor_07  sensor_08  ...  sensor_43  sensor_44  \
# 0   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 1   76.45975   13.41146   16.13136   15.56713  ...   41.92708  39.641200
# 2   73.54598   13.32465   16.03733   15.61777  ...   41.66666  39.351852
# 3   76.98898   13.31742   16.24711   15.69734  ...   40.88541  39.062500
# 4   76.58897   13.35359   16.21094   15.69734  ...   41.40625  38.773150
#
# ...

# %%
df["machine_status"].value_counts()
# Out:
# NORMAL        205836
# RECOVERING     14477
# BROKEN             7
# Name: machine_status, dtype: int64

# %%
# replacing the rtf_ids
replacement_mapping_dict = {}
id = "machine_status"
for i in range(len(df[id].unique())):
    replacement_mapping_dict[df[id].unique()[i]] = int(i + 1)       # replacing the unique rtf_ids with chronoligcal 1,2,3... since the code in autorul assumes this 
df[id] = df[id].replace(replacement_mapping_dict)  # notice: we are just replacing the UNIQUE values, we are NOT restructuring the whole column from 1-n

# %%
df["machine_status"].value_counts()
# Out:
# 1    205836
# 3     14477
# 2         7
# Name: machine_status, dtype: int64

# %%
plt.scatter(df.index[17000:50000], df["machine_status"][17000:50000])
# [17150:17200]

# %%
plt.plot(df["machine_status"])
